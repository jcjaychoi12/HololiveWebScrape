# %%
import pandas as pd

initial = pd.read_csv("./talent_info.csv")
initial.head()
# Out:
#    Status      English Name Japanese Name  \
# 0  Active       Tokino Sora         ときのそら
# 1  Active         Robocosan         ロボ子さん
# 2  Active     Aki Rosenthal    アキ・ローゼンタール
# 3  Active        Akai Haato         赤井はあと
# 4  Active  Shirakami Fubuki         白上フブキ
#
#                                              Youtube  \
# 0  https://www.youtube.com/channel/UCp6993wxpyDPH...
# 1  https://www.youtube.com/channel/UCDqI2jOz0weum...
# 2  https://www.youtube.com/channel/UCFTLzh12_nrtz...
# 3  https://www.youtube.com/channel/UC1CfXB_kRs3C-...
# 4  https://www.youtube.com/channel/UCdn5BQ06XqgXo...
#
#                              Twitter/X     Birthday Debut Stream  Height  \
# 0      https://twitter.com/tokino_sora       May 15   2017-09-07  160 cm
# 1        https://twitter.com/robocosan       May 23          NaN  154 cm
# 2     https://twitter.com/akirosenthal  February 17   2018-06-01  162 cm
# 3        https://twitter.com/akaihaato    August 10   2018-06-02  154 cm
# ...

# %%
print(initial.columns)
print(initial.isnull().sum())
# Out:
# Index(['Status', 'English Name', 'Japanese Name', 'Youtube', 'Twitter/X',
#        'Birthday', 'Debut Stream', 'Height', 'Unit', 'Illustrator',
#        'Illustrator Link', 'Dreams/Goals', 'Fan Name', 'Hashtags', 'Message',
#        'Regular/Specialty Streams', 'Hobbies/Special Skills', 'Dream',
#        'Catchphrases', 'Hobbies/Special Skills/Likes', 'Regular Streams',
#        'Hobbies', 'Likes', 'Special Skills', 'Debut', 'Makeup charge',
#        'Makeup charge Link', 'Snacks & Drinks During Streams',
#        'New Outfit Designer', 'New Outfit Designer Link', 'Words', 'Fan Mark',
#        'Debut date', 'height', 'illustrator', 'illustrator Link', 'Dreams',
#        'Dreams & goals', 'Hobbies, Likes', 'Nicknames', '3D Modeler',
#        '3D Modeler Link', 'Likes/Regular Streams', 'Favorite Game Genres',
#        'Dislikes', 'Referred to as:', 'Goals', 'IllustratorLive2D Designer',
#        'IllustratorLive2D Designer Link', 'Heigh', 'First Appearance', 'Memes',
# ...
